# %%
# !pip install bertopic
# !pip install openai
# !pip install umap-learn
# !pip install hdbscan
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.16.3)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.38.post1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.1.4)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.3.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (3.0.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.5)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.6)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.42.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.3.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.20)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.41.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.3.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.10/dist-packages (0.8.38.post1)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.3.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->hdbscan) (3.5.0)

# %%
import pandas as pd
import openai
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, OpenAI, PartOfSpeech
from sentence_transformers import SentenceTransformer
import pickle
from umap import UMAP
from hdbscan import HDBSCAN

from sklearn.feature_extraction.text import CountVectorizer

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Change to the desired directory in Google Drive
os.chdir('/content/drive/My Drive/Colab Notebooks/Mental Health Depression Bertopic')

# Verify by listing files in the current directory
print(os.listdir())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['data', 'my_model_dir', 'Sentiment Dsitribution and Topic Analysis.ipynb', 'previous reddir small data', 'Depression Data Cleaning and Preprocess', 'DepressionRobertaSentimentAnalysis', 'Topic_modeling_BERTopic.ipynb']

# %%
#Read data
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Mental Health Depression Bertopic/data/depression_sentiments_roberta.csv')

# %%
print(data.shape)
# Out:
# (7730, 10)

# %%
data.head()
# Out:
#    id      label                                           document  \
# 0   0  tensor(0)  we understand that most people who reply immed...
# 1   1  tensor(0)  welcome to r depression s check in post a plac...
# 2   2  tensor(0)  anyone else instead of sleeping more when depr...
# 3   3  tensor(0)  i ve kind of stuffed around a lot in my life d...
# 4   4  tensor(0)  sleep is my greatest and most comforting escap...
#
#    created_utc                                         clean_text  negative  \
# 0            0  understand people reply immediately op invitat...  0.123658
# 1            0  welcome r depression check post place take mom...  0.265393
# 2            0  anyone else instead sleeping depressed stay ni...  0.225754
# 3            0  kind stuffed around lot life delaying inevitab...  0.868262
# 4            0  sleep greatest comforting escape whenever wake...  0.355922
#
#     neutral  positive sentiment        user
# 0  0.683168  0.193175   neutral  depression
# 1  0.642364  0.092243   neutral  depression
# 2  0.600676  0.173570   neutral  depression
# 3  0.117783  0.013955  negative  depression
# 4  0.439947  0.204132   neutral  depression

# %%
print(data.groupby('user').id.nunique())

abstracts = data['clean_text'].astype('str')
# Out:
# user
# control       3900
# depression    3830
# Name: id, dtype: int64

# %%
# Pre-calculate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embedding = embedding_model.encode(abstracts, show_progress_bar=True)

'''with open('doc_embedding.pickle', 'wb') as pkl:
    pickle.dump(embeddings, pkl)'''

'''with open('doc_embedding.pickle', 'rb') as pkl:
    embedding = pickle.load(pkl)'''

umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=42,low_memory=True)

hdbscan_model = HDBSCAN(min_cluster_size=10, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

vectorizer_model = CountVectorizer(stop_words="english", min_df=2, ngram_range=(1, 2))
# Out:
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]

# %%
with open('doc_embedding.pickle', 'wb') as pkl:
    pickle.dump(embedding, pkl)

'''with open('doc_embedding.pickle', 'rb') as pkl:
    embedding = pickle.load(pkl)'''
# Out:
# "with open('doc_embedding.pickle', 'rb') as pkl:\n    embedding = pickle.load(pkl)"

# %%
# KeyBERT
keybert_model = KeyBERTInspired()

# Part-of-Speech
#pos_model = PartOfSpeech("en_core_web_sm")

# MMR
mmr_model = MaximalMarginalRelevance(diversity=0.3)


# All representation models
representation_model = {
    "KeyBERT": keybert_model,
    "MMR": mmr_model,
    #"POS": pos_model
}

# %%
topic_model = BERTopic(

  # Pipeline models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  vectorizer_model=vectorizer_model,
  representation_model=representation_model,

  # Hyperparameters
  top_n_words=10,
  verbose=True
)

topics,prob = topic_model.fit_transform(abstracts, embedding)
topic_model.get_topic_info()
# Out:
# 2024-08-18 22:24:43,616 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-08-18 22:25:33,236 - BERTopic - Dimensionality - Completed ✓
# 2024-08-18 22:25:33,238 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-08-18 22:25:33,914 - BERTopic - Cluster - Completed ✓
# 2024-08-18 22:25:33,925 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-08-18 22:26:18,370 - BERTopic - Representation - Completed ✓
#     Topic  Count                                               Name  \
# 0      -1   2994                         -1_depression_wa_like_feel
# 1       0   1448                                0_life_want_feel_wa
# 2       1    700                        1_anxiety_panic_attack_like
# 3       2    272                          2_sleep_bed_awake_morning
# 4       3    164  3_depression_depression depression_hide depres...
# ..    ...    ...                                                ...
# 80     79     11                   79_mileycyrus_mile_xoxo_counting
# 81     80     11   80_facebook_facebook com_apps facebook_http apps
# 82     81     10      81_late_deadline_stayed late_looking tempting
# 83     82     10          82_hate_money people_gave love_know story
# 84     83     10               83_marley_movie_listening_like movie
#
#                                        Representation  \
# 0   [depression, wa, like, feel, know, day, time, ...
# 1   [life, want, feel, wa, like, friend, know, peo...
# 2   [anxiety, panic, attack, like, anxious, wa, fe...
# 3   [sleep, bed, awake, morning, hour, wake, night...
# 4   [depression, depression depression, hide depre...
# ..                                                ...
# 80  [mileycyrus, mile, xoxo, counting, sleep, bett...
# 81  [facebook, facebook com, apps facebook, http a...
# 82  [late, deadline, stayed late, looking tempting...
# 83  [hate, money people, gave love, know story, st...
# 84  [marley, movie, listening, like movie, night p...
#
#                                               KeyBERT  \
# 0   [depression, depressed, anxiety, feel, feeling...
# 1   [depression, depressed, suicidal, care, feel, ...
# 2   [anxiety attack, anxiety, panic attack, zoloft...
# 3   [sleep, need sleep, sleep sleep, sleeping, abl...
# 4   [depression depression, depression, result dep...
# ..                                                ...
# 80  [mileycyrus, mile, cyrus, mile away, thousand ...
# 81  [apps facebook, dogbook profile, profile view,...
# 82  [deadline, late work, delayed, busy, stayed la...
# 83  [hate, hating, dislike, strongly dislike, real...
# 84  [marley, movie, like movie, going sleep, night...
#
#                                                   MMR  \
# 0   [depression, like, feel, day, work, people, ma...
# 1   [life, friend, feel like, think, family, day, ...
# 2   [anxiety, panic, anxious, panic attack, sympto...
# 3   [morning, woke, slept, going sleep, tired slee...
# 4   [hide depression, depression real, depression ...
# ..                                                ...
# 80  [mileycyrus, mile, xoxo, cyrus, sick love, tho...
# 81  [facebook, facebook com, apps facebook, apps, ...
# 82  [deadline, mutt, spray paint, problem finished...
# 83  [hate, money people, gave love, strongly disli...
# 84  [marley, listening, like movie, night people, ...
#
#                                   Representative_Docs
# 0   [idk guess vent something whatever lately ever...
# 1   [starter never really childhood wa parent woul...
# 2   [whole life dealt trifecta depression anxiety ...
# 3   [cant sleep ugghhh, enough sleep, celesteclara...
# 4   [rsk depression, depression arai, engysmohamed...
# ..                                                ...
# 80  [mileycyrus awww u seriously cutest dog miley ...
# 81  [strider sick little puppy http apps facebook ...
# 82  [damn missed gsoc apply deadline, damn late fi...
# 83  [everyone hate much, never thought could hate ...
# 84  [listening murd th wonder chillen missing craz...
#
# [85 rows x 7 columns]

# %%
df = data.copy()
posts = abstracts.to_list()
ids = df['id'].to_list()
sentiments = df['sentiment'].to_list()
users = df['user'].to_list()
created_utc = df['created_utc'].to_list()
negative = df['negative'].to_list()
neutral = df['neutral'].to_list()
positive = df['positive'].to_list()

# %%
# Reduce outliers with pre-calculate embeddings instead
new_topics = topic_model.reduce_outliers(abstracts, topics, strategy="c-tf-idf")
topic_model.update_topics(abstracts, topics=new_topics)
topic_model.get_topic_info()
# Out:
# 2024-08-18 22:26:36,728 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#     Topic  Count                                             Name  \
# 0      -1     37  -1_snoo_ahhhhhhhhhhhhh_nomadicmatt_featherinair
# 1       0   1994                              0_life_want_feel_wa
# 2       1    843                        1_anxiety_panic_attack_wa
# 3       2    347                        2_sleep_bed_awake_morning
# 4       3    311                      3_depression_co_battle_http
# ..    ...    ...                                              ...
# 80     79     25               79_mileycyrus_hahaha_nite_counting
# 81     80     21                    80_facebook_apps_profile_view
# 82     81     44                        81_late_fb_deadline_spray
# 83     82     37                         82_hate_comment_ohhh_boy
# 84     83     44                       83_movie_hot_listening_rip
#
#                                        Representation  \
# 0   [snoo, ahhhhhhhhhhhhh, nomadicmatt, featherina...
# 1   [life, want, feel, wa, like, know, friend, eve...
# 2   [anxiety, panic, attack, wa, like, anxious, fe...
# 3   [sleep, bed, awake, morning, hour, ugh, night,...
# 4   [depression, co, battle, http, cure, real, sta...
# ..                                                ...
# 80  [mileycyrus, hahaha, nite, counting, ouch, mil...
# 81  [facebook, apps, profile, view, dogbook, com, ...
# 82  [late, fb, deadline, spray, delayed, unfortuna...
# 83  [hate, comment, ohhh, boy, ride, update, oanhl...
# 84  [movie, hot, listening, rip, snoo, film, marle...
#
#                                               KeyBERT  \
# 0   [depression, depressed, anxiety, feel, feeling...
# 1   [depression, depressed, suicidal, care, feel, ...
# 2   [anxiety attack, anxiety, panic attack, zoloft...
# 3   [sleep, need sleep, sleep sleep, sleeping, abl...
# 4   [depression depression, depression, result dep...
# ..                                                ...
# 80  [mileycyrus, mile, cyrus, mile away, thousand ...
# 81  [apps facebook, dogbook profile, profile view,...
# 82  [deadline, late work, delayed, busy, stayed la...
# 83  [hate, hating, dislike, strongly dislike, real...
# 84  [marley, movie, like movie, going sleep, night...
#
#                                                   MMR  \
# 0   [depression, like, feel, day, work, people, ma...
# 1   [life, friend, feel like, think, family, day, ...
# 2   [anxiety, panic, anxious, panic attack, sympto...
# 3   [morning, woke, slept, going sleep, tired slee...
# 4   [hide depression, depression real, depression ...
# ..                                                ...
# 80  [mileycyrus, mile, xoxo, cyrus, sick love, tho...
# 81  [facebook, facebook com, apps facebook, apps, ...
# 82  [deadline, mutt, spray paint, problem finished...
# 83  [hate, money people, gave love, strongly disli...
# 84  [marley, listening, like movie, night people, ...
#
#                                   Representative_Docs
# 0   [idk guess vent something whatever lately ever...
# 1   [starter never really childhood wa parent woul...
# 2   [whole life dealt trifecta depression anxiety ...
# 3   [cant sleep ugghhh, enough sleep, celesteclara...
# 4   [rsk depression, depression arai, engysmohamed...
# ..                                                ...
# 80  [mileycyrus awww u seriously cutest dog miley ...
# 81  [strider sick little puppy http apps facebook ...
# 82  [damn missed gsoc apply deadline, damn late fi...
# 83  [everyone hate much, never thought could hate ...
# 84  [listening murd th wonder chillen missing craz...
#
# [85 rows x 7 columns]

# %%
# This part is removed, we have much less topics than the original research
"""
# reduce topics
topic_model.reduce_topics(abstracts, nr_topics='auto')

# Access updated topics
topics = topic_model.topics_
topic_model.get_topic_info()
"""

# %%
# Access updated topics
topics = topic_model.topics_
topic_model.get_topic_info()
# Out:
#     Topic  Count                                             Name  \
# 0      -1     37  -1_snoo_ahhhhhhhhhhhhh_nomadicmatt_featherinair
# 1       0   1994                              0_life_want_feel_wa
# 2       1    843                        1_anxiety_panic_attack_wa
# 3       2    347                        2_sleep_bed_awake_morning
# 4       3    311                      3_depression_co_battle_http
# ..    ...    ...                                              ...
# 80     79     25               79_mileycyrus_hahaha_nite_counting
# 81     80     21                    80_facebook_apps_profile_view
# 82     81     44                        81_late_fb_deadline_spray
# 83     82     37                         82_hate_comment_ohhh_boy
# 84     83     44                       83_movie_hot_listening_rip
#
#                                        Representation  \
# 0   [snoo, ahhhhhhhhhhhhh, nomadicmatt, featherina...
# 1   [life, want, feel, wa, like, know, friend, eve...
# 2   [anxiety, panic, attack, wa, like, anxious, fe...
# 3   [sleep, bed, awake, morning, hour, ugh, night,...
# 4   [depression, co, battle, http, cure, real, sta...
# ..                                                ...
# 80  [mileycyrus, hahaha, nite, counting, ouch, mil...
# 81  [facebook, apps, profile, view, dogbook, com, ...
# 82  [late, fb, deadline, spray, delayed, unfortuna...
# 83  [hate, comment, ohhh, boy, ride, update, oanhl...
# 84  [movie, hot, listening, rip, snoo, film, marle...
#
#                                               KeyBERT  \
# 0   [depression, depressed, anxiety, feel, feeling...
# 1   [depression, depressed, suicidal, care, feel, ...
# 2   [anxiety attack, anxiety, panic attack, zoloft...
# 3   [sleep, need sleep, sleep sleep, sleeping, abl...
# 4   [depression depression, depression, result dep...
# ..                                                ...
# 80  [mileycyrus, mile, cyrus, mile away, thousand ...
# 81  [apps facebook, dogbook profile, profile view,...
# 82  [deadline, late work, delayed, busy, stayed la...
# 83  [hate, hating, dislike, strongly dislike, real...
# 84  [marley, movie, like movie, going sleep, night...
#
#                                                   MMR  \
# 0   [depression, like, feel, day, work, people, ma...
# 1   [life, friend, feel like, think, family, day, ...
# 2   [anxiety, panic, anxious, panic attack, sympto...
# 3   [morning, woke, slept, going sleep, tired slee...
# 4   [hide depression, depression real, depression ...
# ..                                                ...
# 80  [mileycyrus, mile, xoxo, cyrus, sick love, tho...
# 81  [facebook, facebook com, apps facebook, apps, ...
# 82  [deadline, mutt, spray paint, problem finished...
# 83  [hate, money people, gave love, strongly disli...
# 84  [marley, listening, like movie, night people, ...
#
#                                   Representative_Docs
# 0   [idk guess vent something whatever lately ever...
# 1   [starter never really childhood wa parent woul...
# 2   [whole life dealt trifecta depression anxiety ...
# 3   [cant sleep ugghhh, enough sleep, celesteclara...
# 4   [rsk depression, depression arai, engysmohamed...
# ..                                                ...
# 80  [mileycyrus awww u seriously cutest dog miley ...
# 81  [strider sick little puppy http apps facebook ...
# 82  [damn missed gsoc apply deadline, damn late fi...
# 83  [everyone hate much, never thought could hate ...
# 84  [listening murd th wonder chillen missing craz...
#
# [85 rows x 7 columns]

# %%
d = pd.DataFrame({'ids':ids,'clean_text': posts,'topic': topics, 'probs':prob,'sentiments':sentiments,
                   'users':users,'created_utc':created_utc,'negative':negative,'neutral':neutral,
                 'positive':positive})

d.to_csv("Topic_df_with_sentiments.csv",index=False) # this new datafile contains original data + sentiment labels + topic modeling result

# %%
topics_df = pd.DataFrame(topic_model.get_topic_info())
topics_df.to_csv("Topic_representation.csv",index=False) # this is extra datafile from topic modeling which contains topic representation i.e. 10 words representation,which help us to explore the topics.

# %%
embedding_model = "sentence-transformers/all-MiniLM-L6-v2"
topic_model.save("my_model_dir", serialization="safetensors", save_ctfidf=True, save_embedding_model=embedding_model)

# %%
# Load from directory
loaded_model = BERTopic.load("my_model_dir")
loaded_model.get_topic_info()
# Out:
#     Topic  Count                                             Name  \
# 0      -1     37  -1_snoo_ahhhhhhhhhhhhh_nomadicmatt_featherinair
# 1       0   1994                              0_life_want_feel_wa
# 2       1    843                        1_anxiety_panic_attack_wa
# 3       2    347                        2_sleep_bed_awake_morning
# 4       3    311                      3_depression_co_battle_http
# ..    ...    ...                                              ...
# 80     79     25               79_mileycyrus_hahaha_nite_counting
# 81     80     21                    80_facebook_apps_profile_view
# 82     81     44                        81_late_fb_deadline_spray
# 83     82     37                         82_hate_comment_ohhh_boy
# 84     83     44                       83_movie_hot_listening_rip
#
#                                        Representation  \
# 0   [snoo, ahhhhhhhhhhhhh, nomadicmatt, featherina...
# 1   [life, want, feel, wa, like, know, friend, eve...
# 2   [anxiety, panic, attack, wa, like, anxious, fe...
# 3   [sleep, bed, awake, morning, hour, ugh, night,...
# 4   [depression, co, battle, http, cure, real, sta...
# ..                                                ...
# 80  [mileycyrus, hahaha, nite, counting, ouch, mil...
# 81  [facebook, apps, profile, view, dogbook, com, ...
# 82  [late, fb, deadline, spray, delayed, unfortuna...
# 83  [hate, comment, ohhh, boy, ride, update, oanhl...
# 84  [movie, hot, listening, rip, snoo, film, marle...
#
#                                               KeyBERT  \
# 0   [depression, depressed, anxiety, feel, feeling...
# 1   [depression, depressed, suicidal, care, feel, ...
# 2   [anxiety attack, anxiety, panic attack, zoloft...
# 3   [sleep, need sleep, sleep sleep, sleeping, abl...
# 4   [depression depression, depression, result dep...
# ..                                                ...
# 80  [mileycyrus, mile, cyrus, mile away, thousand ...
# 81  [apps facebook, dogbook profile, profile view,...
# 82  [deadline, late work, delayed, busy, stayed la...
# 83  [hate, hating, dislike, strongly dislike, real...
# 84  [marley, movie, like movie, going sleep, night...
#
#                                                   MMR  Representative_Docs
# 0   [depression, like, feel, day, work, people, ma...                  NaN
# 1   [life, friend, feel like, think, family, day, ...                  NaN
# 2   [anxiety, panic, anxious, panic attack, sympto...                  NaN
# 3   [morning, woke, slept, going sleep, tired slee...                  NaN
# 4   [hide depression, depression real, depression ...                  NaN
# ..                                                ...                  ...
# 80  [mileycyrus, mile, xoxo, cyrus, sick love, tho...                  NaN
# 81  [facebook, facebook com, apps facebook, apps, ...                  NaN
# 82  [deadline, mutt, spray paint, problem finished...                  NaN
# 83  [hate, money people, gave love, strongly disli...                  NaN
# 84  [marley, listening, like movie, night people, ...                  NaN
#
# [85 rows x 7 columns]

# %%
d.columns
# Out:
# Index(['ids', 'clean_text', 'topic', 'probs', 'sentiments', 'users',
#        'created_utc', 'negative', 'neutral', 'positive'],
#       dtype='object')

# %%
topics_df.columns
# Out:
# Index(['Topic', 'Count', 'Name', 'Representation', 'KeyBERT', 'MMR',
#        'Representative_Docs'],
#       dtype='object')

# %%
topics_df['Representative_Docs'].isna().sum()
# Out:
# 0

# %%
topics_df['Representative_Docs']
# Out:
# 0     [idk guess vent something whatever lately ever...
# 1     [starter never really childhood wa parent woul...
# 2     [whole life dealt trifecta depression anxiety ...
# 3     [cant sleep ugghhh, enough sleep, celesteclara...
# 4     [rsk depression, depression arai, engysmohamed...
#                             ...
# 80    [mileycyrus awww u seriously cutest dog miley ...
# 81    [strider sick little puppy http apps facebook ...
# 82    [damn missed gsoc apply deadline, damn late fi...
# 83    [everyone hate much, never thought could hate ...
# 84    [listening murd th wonder chillen missing craz...
# Name: Representative_Docs, Length: 85, dtype: object

# %%
topics_df['Representation']
# Out:
# 0     [snoo, ahhhhhhhhhhhhh, nomadicmatt, featherina...
# 1     [life, want, feel, wa, like, know, friend, eve...
# 2     [anxiety, panic, attack, wa, like, anxious, fe...
# 3     [sleep, bed, awake, morning, hour, ugh, night,...
# 4     [depression, co, battle, http, cure, real, sta...
#                             ...
# 80    [mileycyrus, hahaha, nite, counting, ouch, mil...
# 81    [facebook, apps, profile, view, dogbook, com, ...
# 82    [late, fb, deadline, spray, delayed, unfortuna...
# 83    [hate, comment, ohhh, boy, ride, update, oanhl...
# 84    [movie, hot, listening, rip, snoo, film, marle...
# Name: Representation, Length: 85, dtype: object

# %%
sorted_topics = topics_df.sort_values(by="Count", ascending=False)

# %%
sorted_topics.loc[0, 'Representation']
# Out:
# ['snoo',
#  'ahhhhhhhhhhhhh',
#  'nomadicmatt',
#  'featherinair',
#  'beeeaaach',
#  'zaibatsu',
#  'kateblogs',
#  'keongzai',
#  'yuddylicious',
#  'marlonjenglish']

# %%
sorted_topics.loc[1, 'Representation']
# Out:
# ['life',
#  'want',
#  'feel',
#  'wa',
#  'like',
#  'know',
#  'friend',
#  'even',
#  'people',
#  'time']

# %% [markdown]
# topic 0 is not very clear, it might be life or friendship

# %%
sorted_topics.loc[2, 'Representation']
# Out:
# ['anxiety',
#  'panic',
#  'attack',
#  'wa',
#  'like',
#  'anxious',
#  'feel',
#  'get',
#  'also',
#  'time']

# %%
print("topic" + str(sorted_topics.loc[2, 'Topic']) +  "is most probably feelings")
# Out:
# topic1is most probably feelings

# %%
sorted_topics
# Out:
#     Topic  Count                                               Name  \
# 1       0   1994                                0_life_want_feel_wa
# 2       1    843                          1_anxiety_panic_attack_wa
# 3       2    347                          2_sleep_bed_awake_morning
# 4       3    311                        3_depression_co_battle_http
# 5       4    244                           4_work_working_bored_day
# ..    ...    ...                                                ...
# 51     50     22               50_birthday_officially_chore_fucking
# 81     80     21                      80_facebook_apps_profile_view
# 77     76     20                             76_puppy_dog_doggie_ur
# 73     72     20  72_border_takeusbacktochina_restricted_fmwangy...
# 61     60     18       60_thelmasherbs_theekween_anxiety_depression
#
#                                        Representation  \
# 1   [life, want, feel, wa, like, know, friend, eve...
# 2   [anxiety, panic, attack, wa, like, anxious, fe...
# 3   [sleep, bed, awake, morning, hour, ugh, night,...
# 4   [depression, co, battle, http, cure, real, sta...
# 5   [work, working, bored, day, office, boring, we...
# ..                                                ...
# 51  [birthday, officially, chore, fucking, happy, ...
# 81  [facebook, apps, profile, view, dogbook, com, ...
# 77  [puppy, dog, doggie, ur, poor, away, bout, dea...
# 73  [border, takeusbacktochina, restricted, fmwang...
# 61  [thelmasherbs, theekween, anxiety, depression,...
#
#                                               KeyBERT  \
# 1   [depression, depressed, suicidal, care, feel, ...
# 2   [anxiety attack, anxiety, panic attack, zoloft...
# 3   [sleep, need sleep, sleep sleep, sleeping, abl...
# 4   [depression depression, depression, result dep...
# 5   [work, work work, working, going work, job, wo...
# ..                                                ...
# 51  [birthday today, spend birthday, today birthda...
# 81  [apps facebook, dogbook profile, profile view,...
# 77  [want puppy, puppy, dog, doggie, breed, really...
# 73  [depression suicidal, word depression, stress ...
# 61  [anxiety thelmasherbs, depression thelmasherbs...
#
#                                                   MMR  \
# 1   [life, friend, feel like, think, family, day, ...
# 2   [anxiety, panic, anxious, panic attack, sympto...
# 3   [morning, woke, slept, going sleep, tired slee...
# 4   [hide depression, depression real, depression ...
# 5   [day work, boring, productive, work today, wor...
# ..                                                ...
# 51  [birthday, birthday im, party, birthday today,...
# 81  [facebook, facebook com, apps facebook, apps, ...
# 77  [puppy, poor, doggie, want puppy, study away, ...
# 73  [border, suicidal attempt, word depression, de...
# 61  [theekween depression, anxiety thelmasherbs, t...
#
#                                   Representative_Docs
# 1   [starter never really childhood wa parent woul...
# 2   [whole life dealt trifecta depression anxiety ...
# 3   [cant sleep ugghhh, enough sleep, celesteclara...
# 4   [rsk depression, depression arai, engysmohamed...
# 5                                  [work, work, work]
# ..                                                ...
# 51  [oh officially birthday happy rd birthday look...
# 81  [strider sick little puppy http apps facebook ...
# 77  [ill make fresh start promise xtra sad puppy f...
# 73  [border restricted victim day day getting engu...
# 61  [theekween depression anxiety thelmasherbs, th...
#
# [84 rows x 7 columns]

# %%
sorted_topics[["Name","Count"]]
# Out:
#                                                  Name  Count
# 1                                 0_life_want_feel_wa   1994
# 2                           1_anxiety_panic_attack_wa    843
# 3                           2_sleep_bed_awake_morning    347
# 4                         3_depression_co_battle_http    311
# 5                            4_work_working_bored_day    244
# ..                                                ...    ...
# 51               50_birthday_officially_chore_fucking     22
# 81                      80_facebook_apps_profile_view     21
# 77                             76_puppy_dog_doggie_ur     20
# 73  72_border_takeusbacktochina_restricted_fmwangy...     20
# 61       60_thelmasherbs_theekween_anxiety_depression     18
#
# [84 rows x 2 columns]

# %%
sorted_topics.loc[6:20,["Name","Count"]]
# Out:
#                                      Name  Count
# 6        5_twitter_tweet_tweetdeck_update    149
# 12                  11_quot_song_album_fm    117
# 17     16_co_http_depression_mentalhealth    114
# 10                9_sick_ill_feeling_hope    105
# 7               6_kal_kutner_penn_episode    104
# 16       15_tomorrow_school_holiday_today     99
# 8           7_hungry_lunch_dinner_chicken     89
# 11                   10_eye_hurt_leg_foot     85
# 14              13_job_interview_work_bos     83
# 18           17_waiting_train_traffic_bus     83
# 9                    8_de_pression_la_est     78
# 15          14_rain_weather_today_raining     75
# 39                        38_wan_na_go_ng     73
# 26               25_amp_quot_sweet_filler     71
# 79            78_miss_missing_friend_love     68
# 48         47_sorry_reply_thanks_tommcfly     67
# 53       52_hear_sorry_stephenkruiser_dog     66
# 24               23_easter_baby_home_miss     66
# 13                12_ko_depression_hai_ke     64
# 27            26_revision_study_paper_omg     61
# 46                   45_awww_lol_aww_poor     60
# 25            24_london_germany_sydney_oh     56
# 70                 69_missed_angel_yep_em     55
# 34         33_feed_stats_great_depression     55
# 22                  21_title_damn_dun_pls     54
# 66                   65_hey_luck_saw_line     53
# 56             55_sad_whine_wyldceltic_oh     53
# 28      27_laptop_computer_window_macbook     51
# 45            44_photo_picture_upload_pic     50
# 60                59_boo_season_aint_haha     49
# 21    20_sneaker_mizzzidc_shoe_depression     48
# 74              73_com_http_tinyurl_plurk     48
# 19        18_headache_migraine_ha_massive     47
# 64                63_phone_anna_bri_photo     47
# 49                     48_ah_oh_whack_ahh     46
# 62       61_internet_website_error_ubuntu     45
# 59            58_tired_yawn_half_fighting     45
# 23  22_thelmasherbs_theekween_heart_break     44
# 36              35_sandra_cantu_girl_poor     44
# 82              81_late_fb_deadline_spray     44
# 31              30_cold_tap_loaded_bunged     44
# 84             83_movie_hot_listening_rip     44
# 54    53_utility_sold_nickynocky_exchange     42
# 65        64_ticket_closed_expensive_gear     42
# 42        41_depression_mental_illness_co     42
# 37          36_twitpic_com_http_broadband     42
# 20          19_throat_sore_coughing_cough     41

# %% [markdown]
# By looking at names if we make guesses we have the following topics:

# %%
Topic_names = ["life","anxiety","sleep","depression","work","twitter","music","mental health",
               "health and emotional well-being","TV shows","school","food","body parts",
               "job","public transport","french","weather"]
